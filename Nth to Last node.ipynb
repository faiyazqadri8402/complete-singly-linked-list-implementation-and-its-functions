# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
    def print_list(self):
        cur_node = self.head
        while cur_node:
            print(cur_node.data)
            cur_node = cur_node.next
            
        
        
    def append(self,data):
        new_node = Node(data)
        
        if self.head is None:
            self.head = new_node
            return
        
        last_node = self.head
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node 
        
        
    def prepend(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head = new_node
        
    def length(self):
        cur_node = self.head
        count = 0
        while cur_node:
            count+=1
            cur_node = cur_node.next
        return count    
        
    #1st method
   # def nth_to_last(self,n):
        #total_len = self.length()
        #cur_node = self.head
        #while cur_node:
            #if total_len == n:
             #   print(cur_node.data)
              #  return cur_node
            #total_len-=1
           # cur_node = cur_node.next
        #if cur_node is None:
         #   return
      
    
    # 2nd method
    def print_nth_to_last(self,n):
        p = self.head
        q = self.head
        count = 0
        while q and count<n:
            q = q.next
            count+=1
        if not q:
            print(str(n) + "not in the range of list.")
            return
        while p and q:
            p = p.next
            q = q.next
        return p.data   
    
    # no of data occurences
    def no_occurrences(self,data):
        cur_node = self.head
        count = 0
        while cur_node:
            if cur_node.data == data:
                count+=1
            cur_node = cur_node.next
        return count   
    
    # 2nd method
    def recurssive_occurrences(self,node,data):
        if not node:
            return 0
        if node.data==data:
            return 1+self.recurssive_occurrences(node.next,data)
        else:
            return self.recurssive_occurrences(node.next,data)
        
    # Rotate list
    def rotate(self,k):
        p = self.head
        q = self.head
        prev = None
        count = 0
        while p and count<k:
            prev = p
            p = p.next
            q = q.next
            count+=1
        p = prev
        while q:
            prev = q
            q = q.next
        q = prev
        
        q.next = self.head
        self.head = p.next
        p.next = None
        
    # PALLINDROME
    def ispallindrome(self):
        curnode = self.head
        mystr = ""
        while curnode:
            mystr+=curnode.data
            curnode = curnode.next
        return mystr == mystr[::-1]
    
    # move tail to head
    def move_tail_to_head(self):
        last = self.head
        prev = None
        while last.next:
            prev = last
            last = last.next
        last.next = self.head
        prev.next = None
        self.head = last
            
    # sum two list
    def sum_two_lists(self,llist):
        lst1 = []
        lst2 = []
        str1 = ""
        str2 = ""
        cur1 = self.head
        cur2 = llist.head
        while cur1:
            lst1.insert(0,cur1.data)
            cur1 = cur1.next
        while cur2:
            lst2.insert(0,cur1.data)
            cur2 = cur2.next
        print(lst1)
        print("\n")
        print(lst2)
        for num in lst1:
            str1 += num
        for num in lst2:
            str2 += num
        return int(sum1) + int(sum2)

# %%
llist = LinkedList()
llist.append(1)
llist.append(2)
llist.append(3)

# %%
llist2 = LinkedList()
llist2.append(2)
llist2.append(1)
llist2.append(3)

# %%
llist.sum_two_lists(llist2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-d537113b07d5> in <module>
# ----> 1 llist.sum_two_lists(llist2)
#
# <ipython-input-96-3bb266562f7c> in sum_two_lists(self, llist)
#     146             cur1 = cur1.next
#     147         while cur2:
# --> 148             lst2.insert(0,cur1.data)
#     149             cur2 = cur2.next
#     150         print(lst1)
#
# AttributeError: 'NoneType' object has no attribute 'data'
